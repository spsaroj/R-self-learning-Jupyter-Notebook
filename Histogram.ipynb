# %% [markdown]
# # R programming
#
# The link for my resource is [Here](https://www.youtube.com/watch?v=_V8eKsto3Ug)

# %%
library(datasets) #loading the dataset

# %%
hist(iris$Sepal.Length)
hist(iris$Sepal.Width)
hist(iris$Petal.Length)
hist(iris$Petal.Width)
# Out:
# Plot with title "Histogram of iris$Sepal.Length"
# Plot with title "Histogram of iris$Sepal.Width"
# Plot with title "Histogram of iris$Petal.Length"
# Plot with title "Histogram of iris$Petal.Width"

# %% [markdown]
# ## Histogram by groups
#
# In our database we have 3 different species of Iris. So, to see them side by side, we use this approach.
# This approach is known as small multiples.
#
# par(mfrow = c(3, 1))      #Put graphs in 3 rows and 1 column
# where par means parameter, c is concatinating (treat these 2 numbers as a single unit.),

# %%
par(mfrow = c(3, 1))

# %% [markdown]
# The thing in the [] is selector. selects only setosa in this case. xlim is limit for the x. breaks means how many bars we want in the histogram. main is the title.

# %%
hist(iris$Petal.Width [iris$Species == "setosa"],
  xlim = c(0, 3),
  breaks = 9,
  main = "Petal Width for Setosa",
  xlab = "",
  col = "red")

hist(iris$Petal.Width [iris$Species == "versicolor"],
  xlim = c(0, 3),
  breaks = 9,
  main = "Petal Width for Versicolor",
  xlab = "",
  col = "purple")

hist(iris$Petal.Width [iris$Species == "virginica"],
  xlim = c(0, 3),
  breaks = 9,
  main = "Petal Width for Virginica",
  xlab = "",
  col = "blue")
# Out:
# Plot with title "Petal Width for Setosa"
# Plot with title "Petal Width for Versicolor"
# Plot with title "Petal Width for Virginica"

# %%
# need to change the graphical parameter back to normal
par(mfrow=c(1, 1))
