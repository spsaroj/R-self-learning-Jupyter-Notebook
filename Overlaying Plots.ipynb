# %% [markdown]
# # R programming
#
# The link for my resource is [Here](https://www.youtube.com/watch?v=_V8eKsto3Ug)

# %% [markdown]
# This is for viewing the same thing in different perspective. We get more information and more insight in the same amount of time.

# %%
library(datasets)

head(lynx)
# Out:
# [1]  269  321  585  871 1475 2821

# %%
hist(lynx)
# Out:
# Plot with title "Histogram of lynx"

# %%
hist(lynx,
     breaks = 14,          # "Suggests" 14 bins
     freq   = FALSE,       # Axis shows density, not freq.
     col    = "thistle1",  # Color for histogram
     main   = paste("Histogram of Annual Canadian Lynx",
                    "Trappings, 1821-1934"),
     xlab   = "Number of Lynx Trapped")
# Out:
# Plot with title "Histogram of Annual Canadian Lynx Trappings, 1821-1934"

# %%
hist(lynx,
     breaks = 14,          # "Suggests" 14 bins
     freq   = FALSE,       # Axis shows density, not freq.
     col    = "thistle1",  # Color for histogram
     main   = paste("Histogram of Annual Canadian Lynx",
                    "Trappings, 1821-1934"),
     xlab   = "Number of Lynx Trapped")

curve(dnorm(x, mean = mean(lynx), sd = sd(lynx)),
      col = "thistle4",  # Color of curve
      lwd = 2,           # Line width of 2 pixels
      add = TRUE)        # Superimpose on previous graph. try using false


# Add two kernel density estimators
lines(density(lynx), col = "blue", lwd = 2)
lines(density(lynx, adjust = 3), col = "purple", lwd = 2)
# Out:
# Plot with title "Histogram of Annual Canadian Lynx Trappings, 1821-1934"

# %%
hist(lynx,
     breaks = 14,          # "Suggests" 14 bins
     freq   = FALSE,       # Axis shows density, not freq.
     col    = "thistle1",  # Color for histogram
     main   = paste("Histogram of Annual Canadian Lynx",
                    "Trappings, 1821-1934"),
     xlab   = "Number of Lynx Trapped")

#rug plot
rug(lynx, lwd = 2, col = "gray")
# Out:
# Plot with title "Histogram of Annual Canadian Lynx Trappings, 1821-1934"
